# %% [markdown]
# # Предисловие
#
# Все эти задачи являются исследовательскими, то есть в них нет только одного **правильного** решения или единственно верного результата.
#
# Поэтому вам необходимо обосновать выбор инструментов и способа решения (как это обычно происходит в реальных задачах).

# %% [markdown]
# # Задача 1
# ## Основные темы
# - Линейная алгебра.
# - Теория вероятности.
# - Физика.
#
# ## Описание задачи
#
# Наша цель — научиться обрабатывать значения с датчика силы для весов и выдавать результат в ньютонах (Н).
#
# Чтобы этим датчиком можно было пользоваться, его необходимо откалибровать. Мы можем снять с него только напряжение в вольтах (В).
#
# Для этого была проведена серия экспериментов, где на датчик клали грузы известной массы и после записывали результат. Данные вам предоставлены. Они предварительно не обрабатывались. Это два массива: в первом находятся значения массы приложенного груза в килограммах, а во втором — значения с датчика силы в вольтах.
#
# **Задача:** разработать функцию, которая на вход принимает любые значения с датчика (в вольтах), а возвращает приложенную силу в ньютонах.
#
# ## Конкретные задачи
# 1. Обработайте данные эксперимента, если требуется. Объясните, зачем это необходимо сделать.
# 2. Решите эту задачу, предполагая, что уравнение прямой является лучшим представлением этих данных.
# 3. Решите эту задачу, самостоятельно выбрав функцию представления.
# 4. Сравните ошибки.
#
# *Подсказка:* формально говоря, подбор функции является мультикритериальной задачей оптимизации, так как чем больше параметров в уравнении, тем она будет точнее, но тем сложнее модель, и тем хуже для быстродействия.
#
# **Околооптимальное решение:** ошибка меньше 5.

# %%
U = [ 4.        ,  4.15384615,  4.30769231,  4.46153846,  4.61538462,
        4.76923077,  4.92307692,  5.07692308,  5.23076923,  5.38461538,
        5.53846154,  5.69230769,  5.84615385,  6.        ,  6.15384615,
        6.30769231,  6.46153846,  6.61538462,  6.76923077,  6.92307692,
        7.07692308,  7.23076923,  7.38461538,  7.53846154,  7.69230769,
        7.84615385,  8.        ,  8.15384615,  8.30769231,  8.46153846,
        8.61538462,  8.76923077,  8.92307692,  9.07692308,  9.23076923,
        9.38461538,  9.53846154,  9.69230769,  9.84615385, 10.        ];

# %%
Kg = [10.25070605,  9.5732511 , 10.07275577, 10.994299  , 32.23702137,
        9.42925036, 10.78810607, 10.34323215, 10.60207718, 11.15470675,
       11.25389591, 28.8930596 , 20.86412271, 12.11054727, 17.6861434 ,
       12.89898654, 13.95136032, 13.30545366, 14.00789241, 13.71731726,
       15.97782028, 15.49739681, 16.09024848, 15.61212766, 17.92485695,
       16.21592481, 17.66168379, 18.08787362, 19.70613093, 20.27463807,
       20.11265229, 20.89297677, 20.79889523, 20.82660873, 22.50616809,
       25.30439029, 24.8881944 , 25.59255633, 25.33920882, 26.01389939];

# %% [markdown]
# # Задача 2
# ## Основные темы
# - Линейная алгебра.
# - Кинематика.
#
# ## Описание задачи
#  У нас есть мобильное транспортное средство, которое должно выжить после прохождения трассы. Также есть некоторая предопределённая траектория, которая задана в формате $y(x)$.
#
# Цель — пройти эту траекторию как можно быстрее. Но в конце траектории есть обрыв. Это значит, что в конце пути автомобиль должен остановиться.
#
# Мы должны установить некоторые ограничения, такие как максимальное тангенциальное ускорение (максимальная мощность двигателя), нормальное ускорение (сцепление с дорогой).
#
# Как должен двигаться автомобиль (скорость и ускорение) для решения такой задачи?
#
# **Параметры:**
# $y(x) = Ax \ln (\dfrac{x}{B})$, где $A = 3,\ B = 5$, $x\in [0..4]$
#
# $a_{t_{max}} = 2,\ a_{n_{max}} = 3,\ v_{max} = 3$
#
#
# ## Конкретная задача
# Постройте графики: $y(t),\ v(t),\ a_t(t), a_n(t)$, где $t$ — время в секундах.
#
# *Подсказки:*
# - Трапецеидальная скорость и ускорение: машина должна максимально ускориться вначале (с учётом ограничений), на максимально возможной скорости проехать дистанцию и перед финишем максимально быстро замедлиться.
# - Переход между координатной и натуральной формой.
# - Уравнение кривизны.
# - Эта задача не по теории управления. Ваш автомобиль должен двигаться вдоль траектории идеально.
#
# ## Дополнительный материал
#
# О трапецеидальной скорости. Главная задача дополнительного материала — вытащить формулы для расчёта кривой (в идеале вывести их самостоятельно, так как это чистая геометрия и формулы производной и интеграла).
#
# **На русском:** https://russianblogs.com/article/81463254105/
#
# **На английском:**
#
# - https://core.ac.uk/download/pdf/11224439.pdf (стр. 30–46). Основной материал.
#
# - Spong M. W., Hutchinson S., Vidyasagar M. Robot Dynamics and Control. Vol. 303. — 2004. (стр. 186–191).
#
# Если с английским плохо, то нужно посмотреть только формулы после материала на русском, в противном случае лучше сразу начать с английской литературы.
#
# **Околооптимальное решение:** робот проехал со всеми ограничениями быстрее чем за 6 секунд.

# %% [markdown]
# ![picpic.png](data:image/png;base64,...)

# %% [markdown]
# Изображение: https://robotica.news/kit-costruire-semplicita-un-robot/

# %% [markdown]
# # Задача 3
# ## Основные темы
# - Математический анализ.
# - Дифференциальные уравнения.
# - Теоретическая механика: динамика.
#
# ## Описание задачи
#
# Инженер разработал четырёхзвенный механизм с удлинением, который двигается по нужной траектории и активирует следующий элемент цепочки. Управляемое звено — первое (1). Механизм устанавливается, как на картинке ниже, где указана Gravity (сила тяжести).
#
# Но инженер ушёл и не оставил никаких данных об этом изделии.
#
# Наша глобальная задача — проанализировать механизм, чтобы понять, какие моменты возникают на актуаторе. Это позволит подобрать правильный мотор, который сможет реализовать такую нагрузку.
#
# Так как мы знали, из какого материала сделаны детали, и поняли, что они однородные, то было решено найти массо-инерционные характеристики с помощью CAD-моделирования *(сделано за вас)*.
#
# Во время исследования механизма было замечено, что звенья были подобраны так, что механизм не может крутиться в полный оборот.
#
# ## Конкретные задачи
# 1. Определите пределы углов для управляемого звена (там, где механизм застревает). Для представления результата используйте круговую диаграмму, на которой одним цветом указаны те углы, где механизм работает, а другим — где нет.
# 2. Выберите наибольшее место, где механизм работает, и установите начальный угол мотора в начало этого диапазона (по умолчанию механизм двигается против часовой стрелки).
# 3. Решите обратную задачу динамики, зная, что первый шарнир должен вращаться с постоянным угловым ускорением $0.2\ рад/с^2$.
# 4. Постройте график момента от времени в этом диапазоне.
#
# ## Параметры
# Началом системы координат для каждого тела является его центр масс. Тело в горизонтальном положении. Тогда:
# 1. Тело 1, масса — 0.109 кг, крепление слева [-0.045, 0] м, крепление справа [0.045, 0] м, момент инерции 0.000149 $кг \cdot м^2$.
# 2. Тело 2, масса — 0.166 кг, крепление слева [-0.0534, 0] м, крепление справа [-0.0110, 0] м, момент инерции 0.000256 $кг \cdot м^2$.
# 3. Тело 3, масса — 0.3056 кг, крепление слева [0.00558, -0.0132] м, крепление справа [0.083, -0.0133] м, момент инерции 0.00139 $кг \cdot м^2$.
#
# *Подсказка:* можно решать задачу разными методами (Ньютон — Эйлер, Эйлер — Лагранж).
#
#
# **Околооптимальное решение:** время до заклинивания механизма от 2.7 до 3.5, максимальный момент 0.016 Нм.

# %% [markdown]
# ![task_descr.png](data:image/png;base64,...)

# %% [markdown]
# ![HW_CAE_DYN1_stp.png](data:image/png;base64,...)

# %% [markdown]
# Изображение: Олег Буличев
